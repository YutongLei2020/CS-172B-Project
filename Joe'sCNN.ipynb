# %%
# !git clone https://github.com/YutongLei2020/CS-172B-Project.git
# %cd CS-172B-Project/
# Out:
# Cloning into 'CS-172B-Project'...
# remote: Enumerating objects: 34081, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 34081 (delta 10), reused 3 (delta 1), pack-reused 34058
# Receiving objects: 100% (34081/34081), 58.04 MiB | 18.79 MiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Updating files: 100% (35896/35896), done.
# /content/CS-172B-Project

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import os
import keras
import tensorflow as tf
from tensorflow.keras.models import load_model

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input, Flatten, Conv2D, MaxPool2D
from keras.utils import np_utils
from keras.optimizers import Adam
from keras.regularizers import l2

from keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D

# %%
import load_images_colab as load_images

# %%
X_train, Y_train, X_validation, Y_validation, X_test, Y_test = load_images.getDataset()

# %%
no_of_classes = 7

model = Sequential()

#1st CNN layer
model.add(Conv2D(64,(3,3),padding = 'same',input_shape = (48,48,1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

#2nd CNN layer
model.add(Conv2D(128,(5,5),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#3rd CNN layer
model.add(Conv2D(512,(3,3),padding = 'same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout (0.25))

#4th CNN layer
model.add(Conv2D(512,(3,3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

#Fully connected 1st layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))


# Fully connected layer 2nd layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))

model.add(Dense(no_of_classes, activation='softmax'))

model.summary()



model.compile(
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), 
    optimizer= Adam(learning_rate=0.001), 
    metrics=['accuracy']
)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = 'models/CNN_model', 
        save_freq = 'epoch' ,
        save_best_only = True
    )
]

epoch_num = 30

history = model.fit(X_train, Y_train,batch_size=128,epochs=epoch_num, validation_data=(X_validation, Y_validation),callbacks = callbacks)


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epoch_num)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        640
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 512)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 512)         0
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  batch_normalization_3 (Batc  (None, 6, 6, 512)        2048
#  hNormalization)
#
#  activation_3 (Activation)   (None, 6, 6, 512)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 512)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 256)               0
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation_5 (Activation)   (None, 512)               0
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 4,478,727
# Trainable params: 4,474,759
# Non-trainable params: 3,968
# _________________________________________________________________
# Epoch 1/30
# 169/169 [==============================] - ETA: 0s - loss: 1.8591 - accuracy: 0.2862
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 169/169 [==============================] - 27s 97ms/step - loss: 1.8591 - accuracy: 0.2862 - val_loss: 2.1459 - val_accuracy: 0.2484
# Epoch 2/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.5451 - accuracy: 0.4108
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 169/169 [==============================] - 15s 90ms/step - loss: 1.5452 - accuracy: 0.4108 - val_loss: 1.9427 - val_accuracy: 0.2704
# Epoch 3/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.3631 - accuracy: 0.4747
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 169/169 [==============================] - 15s 90ms/step - loss: 1.3629 - accuracy: 0.4747 - val_loss: 1.6256 - val_accuracy: 0.4030
# Epoch 4/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.2567 - accuracy: 0.5170
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 169/169 [==============================] - 15s 87ms/step - loss: 1.2567 - accuracy: 0.5171 - val_loss: 1.4589 - val_accuracy: 0.4726
# Epoch 5/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.1831 - accuracy: 0.5469
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 169/169 [==============================] - 15s 88ms/step - loss: 1.1829 - accuracy: 0.5469 - val_loss: 1.2287 - val_accuracy: 0.5376
# Epoch 6/30
# 169/169 [==============================] - 11s 67ms/step - loss: 1.1294 - accuracy: 0.5723 - val_loss: 1.2552 - val_accuracy: 0.5257
# Epoch 7/30
# 169/169 [==============================] - 11s 65ms/step - loss: 1.0757 - accuracy: 0.5924 - val_loss: 1.2852 - val_accuracy: 0.5169
# Epoch 8/30
# 168/169 [============================>.] - ETA: 0s - loss: 1.0244 - accuracy: 0.6120
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 169/169 [==============================] - 15s 92ms/step - loss: 1.0244 - accuracy: 0.6120 - val_loss: 1.1579 - val_accuracy: 0.5435
# Epoch 9/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.9808 - accuracy: 0.6277 - val_loss: 1.1725 - val_accuracy: 0.5575
# Epoch 10/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.9379 - accuracy: 0.6451 - val_loss: 1.1976 - val_accuracy: 0.5601
# Epoch 11/30
# 169/169 [==============================] - 12s 68ms/step - loss: 0.8879 - accuracy: 0.6659 - val_loss: 1.3451 - val_accuracy: 0.4799
# Epoch 12/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.8543 - accuracy: 0.6802 - val_loss: 1.1926 - val_accuracy: 0.5566
# Epoch 13/30
# 168/169 [============================>.] - ETA: 0s - loss: 0.7964 - accuracy: 0.6983
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# 169/169 [==============================] - 16s 96ms/step - loss: 0.7967 - accuracy: 0.6982 - val_loss: 1.1394 - val_accuracy: 0.5888
# Epoch 14/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.7597 - accuracy: 0.7146 - val_loss: 1.1855 - val_accuracy: 0.5706
# Epoch 15/30
# 169/169 [==============================] - 11s 67ms/step - loss: 0.7140 - accuracy: 0.7366 - val_loss: 1.4373 - val_accuracy: 0.5189
# Epoch 16/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.6650 - accuracy: 0.7501 - val_loss: 1.2593 - val_accuracy: 0.5727
# Epoch 17/30
# 169/169 [==============================] - 11s 66ms/step - loss: 0.6278 - accuracy: 0.7624 - val_loss: 1.5027 - val_accuracy: 0.5275
# Epoch 18/30
# 169/169 [==============================] - 11s 66ms/step - loss: 0.5776 - accuracy: 0.7869 - val_loss: 1.7219 - val_accuracy: 0.4863
# Epoch 19/30
# 169/169 [==============================] - 11s 66ms/step - loss: 0.5403 - accuracy: 0.7970 - val_loss: 1.3689 - val_accuracy: 0.5713
# Epoch 20/30
# 169/169 [==============================] - 11s 66ms/step - loss: 0.4988 - accuracy: 0.8153 - val_loss: 1.3086 - val_accuracy: 0.5983
# Epoch 21/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.4663 - accuracy: 0.8301 - val_loss: 1.4784 - val_accuracy: 0.5787
# Epoch 22/30
# 169/169 [==============================] - 11s 66ms/step - loss: 0.4329 - accuracy: 0.8403 - val_loss: 1.5015 - val_accuracy: 0.5711
# Epoch 23/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.4060 - accuracy: 0.8516 - val_loss: 1.3718 - val_accuracy: 0.5863
# Epoch 24/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.3866 - accuracy: 0.8604 - val_loss: 1.5182 - val_accuracy: 0.5727
# Epoch 25/30
# 169/169 [==============================] - 11s 66ms/step - loss: 0.3500 - accuracy: 0.8712 - val_loss: 1.6300 - val_accuracy: 0.5589
# Epoch 26/30
# 169/169 [==============================] - 11s 66ms/step - loss: 0.3303 - accuracy: 0.8796 - val_loss: 1.4966 - val_accuracy: 0.5892
# Epoch 27/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.3061 - accuracy: 0.8875 - val_loss: 1.7045 - val_accuracy: 0.5559
# Epoch 28/30
# 169/169 [==============================] - 12s 68ms/step - loss: 0.2893 - accuracy: 0.8949 - val_loss: 1.5537 - val_accuracy: 0.5976
# Epoch 29/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.2827 - accuracy: 0.8967 - val_loss: 1.4779 - val_accuracy: 0.6057
# Epoch 30/30
# 169/169 [==============================] - 12s 69ms/step - loss: 0.2466 - accuracy: 0.9112 - val_loss: 1.8859 - val_accuracy: 0.5717

# %%
print(max(val_acc))
# Out:
# 0.6056848168373108
