# %%
import load_images
import matplotlib.pyplot as plt

# %%
X_train, Y_train, X_validation, Y_validation, X_test, Y_test = load_images.getDataset()

# %%
classes = ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# classes_to_num = {'angry': 0, 'disgusted': 1, 'fearful': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprised': 6}
count = load_images.getDatasetCount()
print(count)
plt.bar(classes,count)
# Out:
# [3995.  436. 4097. 7215. 4965. 4830. 3171.]
# <BarContainer object of 7 artists>

# %%
# Data Visualization grayscale
fig, axes = plt.subplots(3, 3, figsize=(10, 10)) 
for i in range(9):
    img = X_train[i]
    axes[i//3, i%3].imshow(img) # show the image
    label = Y_train[i] 
    axes[i//3, i%3].set_title(f'Label: {label}')

# %%
print(X_train[0])
print(Y_train[0])
# Out:
# [[0.25490198 0.15686275 0.14509805 ... 1.         0.99215686 1.        ]
#  [0.21568628 0.13725491 0.14117648 ... 0.8039216  1.         0.9882353 ]
#  [0.17254902 0.13725491 0.14509805 ... 0.5137255  1.         0.9882353 ]
#  ...
#  [0.18039216 0.2        0.1254902  ... 0.23137255 0.16862746 0.11372549]
#  [0.1764706  0.21176471 0.18431373 ... 0.22745098 0.16862746 0.11764706]
#  [0.18431373 0.19215687 0.20392157 ... 0.16862746 0.14901961 0.12941177]]
# 3

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)

print(Y_train.shape)
print(Y_validation.shape)
print(Y_test.shape)

print(X_train.shape[0]+X_validation.shape[0])
# Out:
# (21532, 48, 48)
# (7177, 48, 48)
# (7178, 48, 48)
# (21532,)
# (7177,)
# (7178,)
# 28709

# %%
X_train, Y_train, X_validation, Y_validation, X_test, Y_test = load_images.getRGBDataset()

# %%
# Data Visualization RGB
fig, axes = plt.subplots(3, 3, figsize=(10, 10)) 
for i in range(9):
    img = X_train[i]
    axes[i//3, i%3].imshow(img) # show the image
    label = Y_train[i] 
    axes[i//3, i%3].set_title(f'Label: {label}')

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)

print(Y_train.shape)
print(Y_validation.shape)
print(Y_test.shape)

print(X_train.shape[0]+X_validation.shape[0])
# Out:
# (21532, 48, 48, 3)
# (7177, 48, 48, 3)
# (7178, 48, 48, 3)
# (21532,)
# (7177,)
# (7178,)
# 28709
