# %%
import load_images
import matplotlib.pyplot as plt

# %%
X_train, Y_train, X_validation, Y_validation, X_test, Y_test = load_images.getDataset()

# %%
classes = ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# classes_to_num = {'angry': 0, 'disgusted': 1, 'fearful': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprised': 6}
count = load_images.getDatasetCount()
print(count)
plt.bar(classes,count)
# Out:
# [16298. 12739. 16400. 19518. 17268. 17133. 15474.]
# <BarContainer object of 7 artists>

# %%
import numpy as np
unique1, counts1 = np.unique(Y_train, return_counts=True)
print(np.asarray((unique1, counts1)))
# Out:
# [[    0     1     2     3     4     5     6]
#  [12223  9554 12300 14638 12951 12850 11606]]

# %%
unique2, counts2 = np.unique(Y_validation, return_counts=True)
print(np.asarray((unique2, counts2)))
# Out:
# [[   0    1    2    3    4    5    6]
#  [4075 3185 4100 4880 4317 4283 3868]]

# %%
print(np.asarray((unique2, counts2/counts1)))
# Out:
# [[0.         1.         2.         3.         4.         5.
#   6.        ]
#  [0.33338788 0.33336822 0.33333333 0.33337888 0.33333333 0.33330739
#   0.33327589]]

# %%
d = {}
for i in Y_train:
    if i not in d:
        d[i] = 0
    else:
        d[i] +=1
print(d)
# Out:
# {4: 12950, 5: 12849, 2: 12299, 0: 12222, 6: 11605, 1: 9553, 3: 14637}

# %%
# Data Visualization grayscale
fig, axes = plt.subplots(5, 5, figsize=(15, 15)) 
for i in range(25):
    img = X_train[i]
    axes[i//5, i%5].imshow(img) # show the image
    label = Y_train[i] 
    axes[i//5, i%5].set_title(f'Label: {classes[label]}')

# %%
print(X_train[0])
print(Y_train[0])
# Out:
# [[[0.79215688 0.64313728 0.34509805]
#   [0.79215688 0.64705884 0.34901962]
#   [0.7980392  0.65098041 0.35294119]
#   ...
#   [0.48333335 0.24901962 0.1382353 ]
#   [0.45980394 0.24117649 0.14215687]
#   [0.41470587 0.22254902 0.14705883]]
#
#  [[0.79215688 0.64313728 0.34509805]
#   [0.79215688 0.64705884 0.34607846]
#   [0.7980392  0.65098041 0.35294119]
#   ...
#   [0.3019608  0.2127451  0.20882353]
#   [0.26960784 0.23529413 0.26666668]
#   [0.32058823 0.34019607 0.40098041]]
#
#  [[0.79019606 0.64215684 0.34313726]
#   [0.79215688 0.64607847 0.34509805]
#   [0.79607844 0.64999998 0.35294119]
#   ...
#   [0.57647061 0.67647064 0.75882351]
#   [0.72254902 0.82352942 0.88627452]
#   [0.82941175 0.90980393 0.94803923]]
#
#  ...
#
#  [[0.74803925 0.60196078 0.31764707]
#   [0.73529416 0.59215689 0.31470591]
#   [0.7166667  0.5745098  0.31078434]
#   ...
#   [0.         0.         0.00882353]
#   [0.00098039 0.00098039 0.01960784]
#   [0.01078431 0.00686275 0.03039216]]
#
#  [[0.64117646 0.50588238 0.26568627]
#   [0.6009804  0.4666667  0.23627451]
#   [0.55588233 0.41862744 0.20294118]
#   ...
#   [0.         0.         0.00784314]
#   [0.         0.         0.01568628]
#   [0.00784314 0.00588235 0.02941177]]
#
#  [[0.43529412 0.29215688 0.12941177]
#   [0.37941176 0.23725492 0.09901962]
#   [0.30980393 0.18529412 0.07352941]
#   ...
#   [0.         0.         0.00686275]
#   [0.         0.         0.01470588]
#   [0.00588235 0.00588235 0.02843137]]]
# 4

# %%
print(X_train[14])
print(Y_train[14])
# Out:
# [[[0.05490196 0.05490196 0.05490196]
#   [0.07843138 0.07843138 0.07843138]
#   [0.03921569 0.03921569 0.03921569]
#   ...
#   [0.07058824 0.07058824 0.07058824]
#   [0.09411765 0.09411765 0.09411765]
#   [0.13725491 0.13725491 0.13725491]]
#
#  [[0.08627451 0.08627451 0.08627451]
#   [0.07450981 0.07450981 0.07450981]
#   [0.05490196 0.05490196 0.05490196]
#   ...
#   [0.04313726 0.04313726 0.04313726]
#   [0.07058824 0.07058824 0.07058824]
#   [0.1254902  0.1254902  0.1254902 ]]
#
#  [[0.12156863 0.12156863 0.12156863]
#   [0.04705882 0.04705882 0.04705882]
#   [0.11372549 0.11372549 0.11372549]
#   ...
#   [0.02745098 0.02745098 0.02745098]
#   [0.05098039 0.05098039 0.05098039]
#   [0.10588235 0.10588235 0.10588235]]
#
#  ...
#
#  [[0.40000001 0.40000001 0.40000001]
#   [0.39215687 0.39215687 0.39215687]
#   [0.39607844 0.39607844 0.39607844]
#   ...
#   [0.11372549 0.11372549 0.11372549]
#   [0.11764706 0.11764706 0.11764706]
#   [0.11764706 0.11764706 0.11764706]]
#
#  [[0.3764706  0.3764706  0.3764706 ]
#   [0.38039216 0.38039216 0.38039216]
#   [0.39215687 0.39215687 0.39215687]
#   ...
#   [0.10196079 0.10196079 0.10196079]
#   [0.10980392 0.10980392 0.10980392]
#   [0.10980392 0.10980392 0.10980392]]
#
#  [[0.37254903 0.37254903 0.37254903]
#   [0.38039216 0.38039216 0.38039216]
#   [0.3882353  0.3882353  0.3882353 ]
#   ...
#   [0.09019608 0.09019608 0.09019608]
#   [0.10196079 0.10196079 0.10196079]
#   [0.10980392 0.10980392 0.10980392]]]
# 3

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)

print(Y_train.shape)
print(Y_validation.shape)
print(Y_test.shape)

print(X_train.shape[0]+X_validation.shape[0])
# Out:
# (86122, 48, 48, 3)
# (28708, 48, 48, 3)
# (7178, 48, 48, 3)
# (86122,)
# (28708,)
# (7178,)
# 114830

# %%
temp = [0,255,255,0,0,255,255,0,0]
temp = np.reshape(temp,(3,3))
plt.imshow(temp)

# %%
temp = [0,1,1,0,0,1,1,0,0]
temp = np.reshape(temp,(3,3))
plt.imshow(temp)
