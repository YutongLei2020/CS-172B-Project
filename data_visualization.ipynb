# %%
import load_images
import matplotlib.pyplot as plt

# %%
X_train, Y_train, X_validation, Y_validation, X_test, Y_test = load_images.getDataset()

# %%
classes = ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# classes_to_num = {'angry': 0, 'disgusted': 1, 'fearful': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprised': 6}
count = load_images.getDatasetCount()
print(count)
plt.bar(classes,count)
# Out:
# [ 7213.  2913.  7273. 12259. 10091.  7921.  7210.]
# <BarContainer object of 7 artists>

# %%
import numpy as np
unique1, counts1 = np.unique(Y_train, return_counts=True)
print(np.asarray((unique1, counts1)))
# Out:
# [[   0    1    2    3    4    5    6]
#  [5410 2185 5455 9194 7568 5941 5407]]

# %%
unique2, counts2 = np.unique(Y_validation, return_counts=True)
print(np.asarray((unique2, counts2)))
# Out:
# [[   0    1    2    3    4    5    6]
#  [1803  728 1818 3065 2523 1980 1803]]

# %%
print(np.asarray((unique2, counts2/counts1)))
# Out:
# [[0.         1.         2.         3.         4.         5.
#   6.        ]
#  [0.33327172 0.33318078 0.33327223 0.33336959 0.33337738 0.33327723
#   0.33345663]]

# %%
d = {}
for i in Y_train:
    if i not in d:
        d[i] = 0
    else:
        d[i] +=1
print(d)
# Out:
# {2: 5454, 5: 5940, 4: 7567, 3: 9193, 0: 5409, 6: 5406, 1: 2184}

# %%
# Data Visualization grayscale
fig, axes = plt.subplots(5, 5, figsize=(15, 15)) 
for i in range(25):
    img = X_train[i]
    axes[i//5, i%5].imshow(img) # show the image
    label = Y_train[i] 
    axes[i//5, i%5].set_title(f'Label: {classes[label]}')

# %%
print(X_train[0])
print(Y_train[0])
# Out:
# [[[0.14901961 0.14901961 0.14901961]
#   [0.13725491 0.13725491 0.13725491]
#   [0.12156863 0.12156863 0.12156863]
#   ...
#   [0.85882354 0.85882354 0.85882354]
#   [0.67058825 0.67058825 0.67058825]
#   [0.24313726 0.24313726 0.24313726]]
#
#  [[0.13333334 0.13333334 0.13333334]
#   [0.11372549 0.11372549 0.11372549]
#   [0.1254902  0.1254902  0.1254902 ]
#   ...
#   [0.77254903 0.77254903 0.77254903]
#   [0.68235296 0.68235296 0.68235296]
#   [0.23529412 0.23529412 0.23529412]]
#
#  [[0.10588235 0.10588235 0.10588235]
#   [0.11764706 0.11764706 0.11764706]
#   [0.12156863 0.12156863 0.12156863]
#   ...
#   [0.80000001 0.80000001 0.80000001]
#   [0.67058825 0.67058825 0.67058825]
#   [0.28235295 0.28235295 0.28235295]]
#
#  ...
#
#  [[0.10196079 0.10196079 0.10196079]
#   [0.09803922 0.09803922 0.09803922]
#   [0.10196079 0.10196079 0.10196079]
#   ...
#   [0.18431373 0.18431373 0.18431373]
#   [0.18431373 0.18431373 0.18431373]
#   [0.1882353  0.1882353  0.1882353 ]]
#
#  [[0.09803922 0.09803922 0.09803922]
#   [0.09803922 0.09803922 0.09803922]
#   [0.09411765 0.09411765 0.09411765]
#   ...
#   [0.17254902 0.17254902 0.17254902]
#   [0.16862746 0.16862746 0.16862746]
#   [0.16862746 0.16862746 0.16862746]]
#
#  [[0.08627451 0.08627451 0.08627451]
#   [0.09803922 0.09803922 0.09803922]
#   [0.09019608 0.09019608 0.09019608]
#   ...
#   [0.16078432 0.16078432 0.16078432]
#   [0.16078432 0.16078432 0.16078432]
#   [0.15294118 0.15294118 0.15294118]]]
# 2

# %%
print(X_train[3])
print(Y_train[3])
# Out:
# [[[0.50588235 0.62745098 0.72941176]
#   [0.50980392 0.63529412 0.7254902 ]
#   [0.49803922 0.62745098 0.72941176]
#   ...
#   [0.38823529 0.47843137 0.58039216]
#   [0.37254902 0.4745098  0.57254902]
#   [0.34117647 0.47058824 0.56470588]]
#
#  [[0.50980392 0.64313725 0.73333333]
#   [0.51372549 0.63529412 0.72941176]
#   [0.53333333 0.65490196 0.74901961]
#   ...
#   [0.39215686 0.50196078 0.59215686]
#   [0.36862745 0.48627451 0.58039216]
#   [0.35686275 0.47843137 0.58823529]]
#
#  [[0.51764706 0.65098039 0.73333333]
#   [0.52941176 0.64313725 0.74509804]
#   [0.54901961 0.65490196 0.75686275]
#   ...
#   [0.38823529 0.50196078 0.59607843]
#   [0.37254902 0.49411765 0.59607843]
#   [0.36470588 0.48235294 0.6       ]]
#
#  ...
#
#  [[0.18431373 0.14901961 0.08627451]
#   [0.1254902  0.09803922 0.04313725]
#   [0.10196078 0.08235294 0.01960784]
#   ...
#   [0.39215686 0.3254902  0.20392157]
#   [0.33333333 0.27058824 0.1372549 ]
#   [0.50588235 0.45098039 0.30980392]]
#
#  [[0.11764706 0.09019608 0.02352941]
#   [0.1254902  0.09411765 0.04313725]
#   [0.14901961 0.11764706 0.06666667]
#   ...
#   [0.36862745 0.30196078 0.18823529]
#   [0.27058824 0.20784314 0.09411765]
#   [0.27843137 0.22352941 0.11372549]]
#
#  [[0.17254902 0.15294118 0.08627451]
#   [0.18431373 0.15686275 0.08627451]
#   [0.19607843 0.15686275 0.10588235]
#   ...
#   [0.35686275 0.29019608 0.17647059]
#   [0.23529412 0.17254902 0.0745098 ]
#   [0.23529412 0.17647059 0.09411765]]]
# 5

# %%
print(X_train.shape)
print(X_validation.shape)
print(X_test.shape)

print(Y_train.shape)
print(Y_validation.shape)
print(Y_test.shape)

print(X_train.shape[0]+X_validation.shape[0])
# Out:
# (41160, 48, 48, 3)
# (13720, 48, 48, 3)
# (7178, 48, 48, 3)
# (41160,)
# (13720,)
# (7178,)
# 54880

# %%
temp = [0,255,255,0,0,255,255,0,0]
temp = np.reshape(temp,(3,3))
plt.imshow(temp)

# %%
temp = [0,1,1,0,0,1,1,0,0]
temp = np.reshape(temp,(3,3))
plt.imshow(temp)
